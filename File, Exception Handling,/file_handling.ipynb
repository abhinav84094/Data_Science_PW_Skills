# %%
file = open("file1.txt", 'r')
content = file.read()
print(content)
# Out:
# Hii I am ABhinav Prkash

# %%
file = open("file1.txt", 'w')
file.close()  #it will delete all the content of the file

# %%
file = open("file1.txt", 'w')
file.write("Hii I am Aman")
file.close()
file = open("file1.txt", 'r')
content = file.read()
print(content)
# Out:
# Hii I am Aman

# %%
file = open('file1.txt', 'a') # it will append the content after previous content
file.write("\nI am learning Python")
file.close()
file = open("file1.txt", 'r')
content = file.read()
print(content)
print(file.read())
print(content)
# Out:
# Hii I am Aman
# I am learning Python
#
# I am learning Python
#
# Hii I am Aman
# I am learning Python
#
# I am learning Python

# %%
print(file.tell())
file.seek(0)  #it will come to 0th cursor point position
print(file.read())
# Out:
# 0
# Hii I am Aman
# I am learning Python
#
# I am learning Python

# %%
file.seek(0)  #it will come to 0th cursor point position
print(file.readlines())
file.seek(0)
print(file.readline())

file.seek(0)
for i in file:
    print(i)
# Out:
# ['Hii I am Aman\n', 'I am learning Python\n', 'I am learning Python']
# Hii I am Aman
#
# Hii I am Aman
#
# I am learning Python
#
# I am learning Python

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os
os.getcwd()
# Out:
# 'a:\\Data Science\\Python\\File Handling,'

# %%
ls
# Out:
#  Volume in drive A is Computer Files
#  Volume Serial Number is 52FC-302F
#
#  Directory of a:\Data Science\Python\File Handling,
#
# 19-11-2025  10:18    <DIR>          .
# 09-11-2025  14:29    <DIR>          ..
# 19-11-2025  10:41             4,421 file_handling.ipynb
# 19-11-2025  10:35                57 file1.txt
#                2 File(s)          4,478 bytes
#                2 Dir(s)  40,170,807,296 bytes free

# %%
os.path.getsize('file1.txt')
# Out:
# 57

# %%
os.mkdir("test")
